# %%
import pandas as pd 
import matplotlib.pyplot as plt

# %%
Nypd_df = pd.read_csv('NYPD_Complaint_Data_Historic.csv')
# Out:
# /home/calvinyu/miniconda3/envs/metis/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3155: DtypeWarning: Columns (17) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,

# %%
Nypd_df
# Out:
#          CMPLNT_NUM CMPLNT_FR_DT CMPLNT_FR_TM CMPLNT_TO_DT CMPLNT_TO_TM  \
# 0         101109527   12/31/2015     23:45:00          NaN          NaN
# 1         153401121   12/31/2015     23:36:00          NaN          NaN
# 2         569369778   12/31/2015     23:30:00          NaN          NaN
# 3         968417082   12/31/2015     23:30:00          NaN          NaN
# 4         641637920   12/31/2015     23:25:00   12/31/2015     23:30:00
# ...             ...          ...          ...          ...          ...
# 1048570   317154175    11/1/2013     20:30:00    11/1/2013     21:00:00
# 1048571   833410354    11/1/2013     20:28:00    11/1/2013     20:31:00
# 1048572   961949188    11/1/2013     20:25:00          NaN          NaN
# 1048573   157608118    11/1/2013     20:25:00    11/1/2013     20:45:00
# 1048574   176151924    11/1/2013     20:25:00    11/1/2013     20:30:00
#
#              RPT_DT  KY_CD                        OFNS_DESC  PD_CD  \
# ...

# %%
Nypd_df.tail(5)
# Out:
#          CMPLNT_NUM CMPLNT_FR_DT CMPLNT_FR_TM CMPLNT_TO_DT CMPLNT_TO_TM  \
# 1048570   317154175    11/1/2013     20:30:00    11/1/2013     21:00:00
# 1048571   833410354    11/1/2013     20:28:00    11/1/2013     20:31:00
# 1048572   961949188    11/1/2013     20:25:00          NaN          NaN
# 1048573   157608118    11/1/2013     20:25:00    11/1/2013     20:45:00
# 1048574   176151924    11/1/2013     20:25:00    11/1/2013     20:30:00
#
#             RPT_DT  KY_CD                       OFNS_DESC  PD_CD  \
# 1048570  11/1/2013    341                   PETIT LARCENY  338.0
# 1048571  11/1/2013    344    ASSAULT 3 & RELATED OFFENSES  113.0
# 1048572  11/1/2013    121  CRIMINAL MISCHIEF & RELATED OF  269.0
# 1048573  11/1/2013    235                 DANGEROUS DRUGS  511.0
# 1048574  11/1/2013    236               DANGEROUS WEAPONS  782.0
#
#                                 PD_DESC  ... ADDR_PCT_CD LOC_OF_OCCUR_DESC  \
# ...

# %%
Nypd_df["DATE"] = Nypd_df['CMPLNT_FR_DT']

# %%
Nypd_df['TIME'] = Nypd_df['CMPLNT_FR_TM']

# %%
Nypd_df['DateTime'] = Nypd_df['DATE'] + ' ' + Nypd_df['TIME']

# %%
Nypd_df['DateTime'] = pd.to_datetime(Nypd_df['DateTime'],errors = 'coerce')

# %%
Nypd_df.columns
# Out:
# Index(['CMPLNT_NUM', 'CMPLNT_FR_DT', 'CMPLNT_FR_TM', 'CMPLNT_TO_DT',
#        'CMPLNT_TO_TM', 'RPT_DT', 'KY_CD', 'OFNS_DESC', 'PD_CD', 'PD_DESC',
#        'CRM_ATPT_CPTD_CD', 'LAW_CAT_CD', 'JURIS_DESC', 'BORO_NM',
#        'ADDR_PCT_CD', 'LOC_OF_OCCUR_DESC', 'PREM_TYP_DESC', 'PARKS_NM',
#        'HADEVELOPT', 'X_COORD_CD', 'Y_COORD_CD', 'Latitude', 'Longitude',
#        'Lat_Lon', 'DATE', 'TIME', 'DateTime'],
#       dtype='object')

# %%
Nypd_df.groupby(['BORO_NM'])

# %%
Nypd_df_Jan2015 = Nypd_df[Nypd_df['DateTime'].dt.year == 2015]

# %%
Nypd_df_Jan2015 = Nypd_df_Jan2015[Nypd_df_Jan2015['DateTime'].dt.month == 1]

# %%
Nypd_df_Jan2015
# Out:
#         CMPLNT_NUM CMPLNT_FR_DT CMPLNT_FR_TM CMPLNT_TO_DT CMPLNT_TO_TM  \
# 1087     116800663    1/28/2015     12:00:00   12/31/2015     12:00:00
# 1088     840953905     1/1/2015      0:01:00   12/31/2015     17:22:00
# 2352     566385313    1/16/2015      8:00:00   12/30/2015     14:00:00
# 3576     948927767     1/8/2015     23:57:00    1/14/2015     10:00:00
# 8995     395219456     1/1/2015     12:00:00   12/15/2015     12:00:00
# ...            ...          ...          ...          ...          ...
# 478343   287915144     1/1/2015      0:01:00     1/1/2015      1:20:00
# 478344   150847953     1/1/2015      0:00:00     1/1/2015      0:23:00
# 478345   213194762     1/1/2015      0:00:00     1/1/2015      0:05:00
# 478346   124173430     1/1/2015      0:00:00     1/1/2015     13:20:00
# 478347   588593124     1/1/2015      0:00:00     1/1/2015      8:30:00
#
#             RPT_DT  KY_CD                       OFNS_DESC  PD_CD  \
# ...

# %%
Nypd_df_Feb2015 = Nypd_df[Nypd_df['DateTime'].dt.year == 2015]

# %%
Nypd_df_Feb2015 = Nypd_df_Feb2015[Nypd_df_Feb2015['DateTime'].dt.month == 2]

# %%
Nypd_df_Feb2015
# Out:
#         CMPLNT_NUM CMPLNT_FR_DT CMPLNT_FR_TM CMPLNT_TO_DT CMPLNT_TO_TM  \
# 4845     409499586    2/15/2015     10:00:00    2/15/2015     22:00:00
# 7946     967003040    2/24/2015      2:00:00   12/24/2015      2:30:00
# 10208    711042785    2/17/2015     22:00:00    2/17/2015     23:00:00
# 10209    249917809     2/3/2015     12:00:00   12/23/2015     11:00:00
# 11496    823711538    2/20/2015     15:00:00    2/27/2015     14:00:00
# ...            ...          ...          ...          ...          ...
# 443788   162612783     2/1/2015      0:01:00     2/1/2015      8:00:00
# 443789   698786279     2/1/2015      0:01:00     2/1/2015      3:15:00
# 443790   932968997     2/1/2015      0:01:00     2/1/2015      0:30:00
# 443791   409102507     2/1/2015      0:01:00     2/1/2015      0:30:00
# 443792   952414750     2/1/2015      0:00:00     2/1/2015      4:30:00
#
#             RPT_DT  KY_CD                       OFNS_DESC  PD_CD  \
# ...

# %%
Nypd_df_Mar2015 = Nypd_df[Nypd_df['DateTime'].dt.year == 2015]

# %%
Nypd_df_Mar2015 = Nypd_df_Mar2015[Nypd_df_Mar2015['DateTime'].dt.month == 3]

# %%
Nypd_df_Mar2015.tail(5)
# Out:
#         CMPLNT_NUM CMPLNT_FR_DT CMPLNT_FR_TM CMPLNT_TO_DT CMPLNT_TO_TM  \
# 412269   267290152     3/1/2015      0:01:00     3/1/2015      0:15:00
# 412270   544852794     3/1/2015      0:01:00     3/1/2015      2:00:00
# 412271   941780464     3/1/2015      0:01:00     3/1/2015      1:00:00
# 412272   982674472     3/1/2015      0:00:00     3/1/2015     13:00:00
# 412273   292165338     3/1/2015      0:00:00     3/1/2015     23:30:00
#
#           RPT_DT  KY_CD                     OFNS_DESC  PD_CD  \
# 412269  3/1/2015    578                 HARRASSMENT 2  637.0
# 412270  3/1/2015    341                 PETIT LARCENY  338.0
# 412271  3/1/2015    344  ASSAULT 3 & RELATED OFFENSES  101.0
# 412272  3/1/2015    341                 PETIT LARCENY  338.0
# 412273  3/1/2015    578                 HARRASSMENT 2  637.0
#
#                                PD_DESC  ... PARKS_NM HADEVELOPT X_COORD_CD  \
# 412269      HARASSMENT,SUBD 1,CIVILIAN  ...      NaN        NaN  1008745.0
# ...

# %%
Nypd_df_Jan_to_Mar = pd.concat([Nypd_df_Jan2015,Nypd_df_Feb2015,Nypd_df_Mar2015])

# %%
Nypd_df_Jan_to_Mar
# Out:
#         CMPLNT_NUM CMPLNT_FR_DT CMPLNT_FR_TM CMPLNT_TO_DT CMPLNT_TO_TM  \
# 1087     116800663    1/28/2015     12:00:00   12/31/2015     12:00:00
# 1088     840953905     1/1/2015      0:01:00   12/31/2015     17:22:00
# 2352     566385313    1/16/2015      8:00:00   12/30/2015     14:00:00
# 3576     948927767     1/8/2015     23:57:00    1/14/2015     10:00:00
# 8995     395219456     1/1/2015     12:00:00   12/15/2015     12:00:00
# ...            ...          ...          ...          ...          ...
# 412269   267290152     3/1/2015      0:01:00     3/1/2015      0:15:00
# 412270   544852794     3/1/2015      0:01:00     3/1/2015      2:00:00
# 412271   941780464     3/1/2015      0:01:00     3/1/2015      1:00:00
# 412272   982674472     3/1/2015      0:00:00     3/1/2015     13:00:00
# 412273   292165338     3/1/2015      0:00:00     3/1/2015     23:30:00
#
#             RPT_DT  KY_CD                       OFNS_DESC  PD_CD  \
# ...

# %%
Nypd_df_Jan_to_Mar['BORO_NM'].hist()
# Out:
# <AxesSubplot:>

# %%
Nypd = Nypd_df_Jan_to_Mar.groupby(['DATE', 'BORO_NM'])[['BORO_NM']].count()

# %%
Nypd
# Out:
#                         BORO_NM
# DATE     BORO_NM
# 1/1/2015 BRONX              305
#          BROOKLYN           627
#          MANHATTAN          430
#          QUEENS             340
#          STATEN ISLAND       69
# ...                         ...
# 3/9/2015 BRONX              259
#          BROOKLYN           367
#          MANHATTAN          288
#          QUEENS             265
#          STATEN ISLAND      114
#
# [450 rows x 1 columns]

# %%
Nypd.rename({'BORO_NM' : 'Daily Entries'}, inplace = True,axis = 'columns')

# %%
Nypd.reset_index(0,inplace = True)

# %%
Nypd.reset_index(0,inplace = True)

# %%
Nypd
# Out:
#            BORO_NM      DATE  Daily Entries
# 0            BRONX  1/1/2015            305
# 1         BROOKLYN  1/1/2015            627
# 2        MANHATTAN  1/1/2015            430
# 3           QUEENS  1/1/2015            340
# 4    STATEN ISLAND  1/1/2015             69
# ..             ...       ...            ...
# 445          BRONX  3/9/2015            259
# 446       BROOKLYN  3/9/2015            367
# 447      MANHATTAN  3/9/2015            288
# 448         QUEENS  3/9/2015            265
# 449  STATEN ISLAND  3/9/2015            114
#
# [450 rows x 3 columns]

# %%
Nypd['DATE'] = pd.to_datetime(Nypd['DATE'])

# %%
Nypd['DATE'] = sorted(Nypd['DATE'])

# %%
Nypd['DATE']
# Out:
# 0     2015-01-01
# 1     2015-01-01
# 2     2015-01-01
# 3     2015-01-01
# 4     2015-01-01
#          ...
# 445   2015-03-31
# 446   2015-03-31
# 447   2015-03-31
# 448   2015-03-31
# 449   2015-03-31
# Name: DATE, Length: 450, dtype: datetime64[ns]

# %%
import seaborn as sns
sns.set(rc={'figure.figsize':(11.7,8.27)})

# %%
sns.lineplot(data = Nypd , x = 'DATE' , y = 'Daily Entries' , hue = 'BORO_NM')
# Out:
# <AxesSubplot:xlabel='DATE', ylabel='Daily Entries'>

# %%
import urllib.request

url = "http://web.mta.info/developers/data/nyct/turnstile/turnstile_{}.txt"
week_nums = [150103,150110,150117,150124,150131,150207,150214,150221,150228,150307,150314,150321,150328,150404]

for week_num in week_nums:
    urllib.request.urlretrieve(f"http://web.mta.info/developers/data/nyct/turnstile/turnstile_{week_num}.txt",
                               f"turnstile_{week_num}.txt")

# %%
from sqlalchemy import create_engine
import pandas as pd

engine = create_engine("sqlite:///mta.db")
all_data = pd.read_sql('SELECT * FROM mta_data;', engine)

# %%
all_data.head(5)
# Out:
#      CA  UNIT       SCP        STATION  LINENAME  DIVISION        DATE  \
# 0   C/A  UNIT       SCP        STATION  LINENAME  DIVISION        DATE
# 1  A002  R051  02-00-00  LEXINGTON AVE    NQR456       BMT  12/27/2014
# 2  A002  R051  02-00-00  LEXINGTON AVE    NQR456       BMT  12/27/2014
# 3  A002  R051  02-00-00  LEXINGTON AVE    NQR456       BMT  12/27/2014
# 4  A002  R051  02-00-00  LEXINGTON AVE    NQR456       BMT  12/27/2014
#
#        TIME     DESC  ENTRIES  \
# 0      TIME     DESC  ENTRIES
# 1  03:00:00  REGULAR  4936840
# 2  07:00:00  REGULAR  4936852
# 3  11:00:00  REGULAR  4936909
# 4  15:00:00  REGULAR  4937131
#
#                                                EXITS
# 0  EXITS                                         ...
# 1                                            1672747
# 2                                            1672762
# 3                                            1672839
# 4                                            1672892

# %%
all_data
# Out:
#             CA  UNIT       SCP        STATION LINENAME DIVISION        DATE  \
# 1         A002  R051  02-00-00  LEXINGTON AVE   NQR456      BMT  12/27/2014
# 7         A002  R051  02-00-00  LEXINGTON AVE   NQR456      BMT  12/28/2014
# 13        A002  R051  02-00-00  LEXINGTON AVE   NQR456      BMT  12/29/2014
# 19        A002  R051  02-00-00  LEXINGTON AVE   NQR456      BMT  12/30/2014
# 25        A002  R051  02-00-00  LEXINGTON AVE   NQR456      BMT  12/31/2014
# ...        ...   ...       ...            ...      ...      ...         ...
# 2701834  TRAM2  R469  00-05-01  RIT-ROOSEVELT        R      RIT  03/30/2015
# 2701840  TRAM2  R469  00-05-01  RIT-ROOSEVELT        R      RIT  03/31/2015
# 2701846  TRAM2  R469  00-05-01  RIT-ROOSEVELT        R      RIT  04/01/2015
# 2701852  TRAM2  R469  00-05-01  RIT-ROOSEVELT        R      RIT  04/02/2015
# 2701858  TRAM2  R469  00-05-01  RIT-ROOSEVELT        R      RIT  04/03/2015
#
# ...

# %%
all_data['DATE']
# Out:
# 0                DATE
# 1          12/27/2014
# 2          12/27/2014
# 3          12/27/2014
# 4          12/27/2014
#               ...
# 2701859    04/03/2015
# 2701860    04/03/2015
# 2701861    04/03/2015
# 2701862    04/03/2015
# 2701863    04/03/2015
# Name: DATE, Length: 2701864, dtype: object

# %%
all_data = all_data.drop(0)

# %%
all_data['DateTime'] = all_data['DATE'] + ' ' + all_data['TIME']

# %%
all_data['DateTime'] =  pd.to_datetime(all_data['DateTime'])

# %%
all_data['DateTime'].head()
# Out:
# 1   2014-12-27 03:00:00
# 2   2014-12-27 07:00:00
# 3   2014-12-27 11:00:00
# 4   2014-12-27 15:00:00
# 5   2014-12-27 19:00:00
# Name: DateTime, dtype: datetime64[ns]

# %%
all_data.DATE.tail()
# Out:
# 2701859    04/03/2015
# 2701860    04/03/2015
# 2701861    04/03/2015
# 2701862    04/03/2015
# 2701863    04/03/2015
# Name: DATE, dtype: object

# %%
all_data.columns = [column.strip() for column in all_data.columns]
all_data.columns
# Out:
# Index(['CA', 'UNIT', 'SCP', 'STATION', 'LINENAME', 'DIVISION', 'DATE', 'TIME',
#        'DESC', 'ENTRIES', 'EXITS', 'DateTime'],
#       dtype='object')

# %%
all_data.DATE.value_counts().sort_index()
# Out:
# 01/01/2015    27458
# 01/02/2015    28405
# 01/03/2015    27180
# 01/04/2015    27129
# 01/05/2015    27819
#               ...
# 12/27/2014    27655
# 12/28/2014    27200
# 12/29/2014    27726
# 12/30/2014    27887
# 12/31/2014    27782
# Name: DATE, Length: 98, dtype: int64

# %%
all_data.DateTime
# Out:
# 1         2014-12-27 03:00:00
# 2         2014-12-27 07:00:00
# 3         2014-12-27 11:00:00
# 4         2014-12-27 15:00:00
# 5         2014-12-27 19:00:00
#                   ...
# 2701859   2015-04-03 05:00:00
# 2701860   2015-04-03 09:00:00
# 2701861   2015-04-03 13:00:00
# 2701862   2015-04-03 17:00:00
# 2701863   2015-04-03 21:00:00
# Name: DateTime, Length: 2701863, dtype: datetime64[ns]

# %%
all_data.head()
# Out:
#      CA  UNIT       SCP        STATION LINENAME DIVISION        DATE  \
# 1  A002  R051  02-00-00  LEXINGTON AVE   NQR456      BMT  12/27/2014
# 2  A002  R051  02-00-00  LEXINGTON AVE   NQR456      BMT  12/27/2014
# 3  A002  R051  02-00-00  LEXINGTON AVE   NQR456      BMT  12/27/2014
# 4  A002  R051  02-00-00  LEXINGTON AVE   NQR456      BMT  12/27/2014
# 5  A002  R051  02-00-00  LEXINGTON AVE   NQR456      BMT  12/27/2014
#
#        TIME     DESC  ENTRIES    EXITS            DateTime
# 1  03:00:00  REGULAR  4936840  1672747 2014-12-27 03:00:00
# 2  07:00:00  REGULAR  4936852  1672762 2014-12-27 07:00:00
# 3  11:00:00  REGULAR  4936909  1672839 2014-12-27 11:00:00
# 4  15:00:00  REGULAR  4937131  1672892 2014-12-27 15:00:00
# 5  19:00:00  REGULAR  4937588  1672949 2014-12-27 19:00:00

# %%
all_data.groupby(["CA", "UNIT", "SCP", "STATION", "DateTime"]).ENTRIES.count().reset_index().sort_values("ENTRIES", ascending=False).head(5)
# Out:
#            CA  UNIT       SCP         STATION            DateTime  ENTRIES
# 1773180  R138  R293  00-03-01  34 ST-PENN STA 2015-02-28 05:00:00        2
# 614006   N020  R101  00-00-05          145 ST 2015-02-18 23:00:00        2
# 2297217  R323  R387  00-00-03   E TREMONT AVE 2015-04-02 01:00:00        2
# 2180754  R256  R182  00-00-03          116 ST 2015-02-24 04:00:00        2
# 2158394  R249  R179  01-00-06           86 ST 2015-01-17 11:00:00        2

# %%
all_data.drop_duplicates(subset=["CA", "UNIT", "SCP", "STATION", "DATE"], inplace=True)

# %%
all_data.groupby(["CA", "UNIT", "SCP", "STATION", "DATE"]).ENTRIES.count().reset_index().sort_values("ENTRIES", ascending=False).head(5)
# Out:
#           CA  UNIT       SCP         STATION        DATE  ENTRIES
# 0       A002  R051  02-00-00   LEXINGTON AVE  01/01/2015        1
# 297058  R145  R032  00-00-02  42 ST-TIMES SQ  02/09/2015        1
# 297069  R145  R032  00-00-02  42 ST-TIMES SQ  02/20/2015        1
# 297068  R145  R032  00-00-02  42 ST-TIMES SQ  02/19/2015        1
# 297067  R145  R032  00-00-02  42 ST-TIMES SQ  02/18/2015        1

# %%
all_data_daily = (all_data
                        .groupby(["CA", "UNIT", "SCP", "STATION", "DATE"],as_index=False)
                        .ENTRIES.first())

# %%
all_data_daily[["PREV_DATE", "PREV_ENTRIES"]] = all_data_daily.groupby(["CA", "UNIT", "SCP", "STATION"])["DATE", "ENTRIES"].apply(lambda grp: grp.shift(1))
# Out:
# <ipython-input-50-019c3df963e6>:1: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   all_data_daily[["PREV_DATE", "PREV_ENTRIES"]] = all_data_daily.groupby(["CA", "UNIT", "SCP", "STATION"])["DATE", "ENTRIES"].apply(lambda grp: grp.shift(1))

# %%
all_data_daily.head()
# Out:
#      CA  UNIT       SCP        STATION        DATE  ENTRIES   PREV_DATE  \
# 0  A002  R051  02-00-00  LEXINGTON AVE  01/01/2015  4943391         NaN
# 1  A002  R051  02-00-00  LEXINGTON AVE  01/02/2015  4944000  01/01/2015
# 2  A002  R051  02-00-00  LEXINGTON AVE  01/03/2015  4945474  01/02/2015
# 3  A002  R051  02-00-00  LEXINGTON AVE  01/04/2015  4946237  01/03/2015
# 4  A002  R051  02-00-00  LEXINGTON AVE  01/05/2015  4946497  01/04/2015
#
#    PREV_ENTRIES
# 0           NaN
# 1     4943391.0
# 2     4944000.0
# 3     4945474.0
# 4     4946237.0

# %%
all_data_daily['DailyVol'] = all_data_daily['ENTRIES'] - all_data_daily['PREV_ENTRIES']

# %%
all_data_daily.head()
# Out:
#      CA  UNIT       SCP        STATION        DATE  ENTRIES   PREV_DATE  \
# 0  A002  R051  02-00-00  LEXINGTON AVE  01/01/2015  4943391         NaN
# 1  A002  R051  02-00-00  LEXINGTON AVE  01/02/2015  4944000  01/01/2015
# 2  A002  R051  02-00-00  LEXINGTON AVE  01/03/2015  4945474  01/02/2015
# 3  A002  R051  02-00-00  LEXINGTON AVE  01/04/2015  4946237  01/03/2015
# 4  A002  R051  02-00-00  LEXINGTON AVE  01/05/2015  4946497  01/04/2015
#
#    PREV_ENTRIES  DailyVol
# 0           NaN       NaN
# 1     4943391.0     609.0
# 2     4944000.0    1474.0
# 3     4945474.0     763.0
# 4     4946237.0     260.0

# %%
all_data_daily.dropna(subset=["PREV_DATE"], axis=0, inplace=True)

# %%
all_data_daily
# Out:
#            CA  UNIT       SCP        STATION        DATE  ENTRIES   PREV_DATE  \
# 1        A002  R051  02-00-00  LEXINGTON AVE  01/02/2015  4944000  01/01/2015
# 2        A002  R051  02-00-00  LEXINGTON AVE  01/03/2015  4945474  01/02/2015
# 3        A002  R051  02-00-00  LEXINGTON AVE  01/04/2015  4946237  01/03/2015
# 4        A002  R051  02-00-00  LEXINGTON AVE  01/05/2015  4946497  01/04/2015
# 5        A002  R051  02-00-00  LEXINGTON AVE  01/06/2015  4948380  01/05/2015
# ...       ...   ...       ...            ...         ...      ...         ...
# 445589  TRAM2  R469  00-05-01  RIT-ROOSEVELT  12/27/2014     5554  04/03/2015
# 445590  TRAM2  R469  00-05-01  RIT-ROOSEVELT  12/28/2014     5554  12/27/2014
# 445591  TRAM2  R469  00-05-01  RIT-ROOSEVELT  12/29/2014     5554  12/28/2014
# 445592  TRAM2  R469  00-05-01  RIT-ROOSEVELT  12/30/2014     5554  12/29/2014
# 445593  TRAM2  R469  00-05-01  RIT-ROOSEVELT  12/31/2014     5554  12/30/2014
#
#         PREV_ENTRIES  DailyVol
# ...

# %%
all_data_daily[all_data_daily["ENTRIES"] < all_data_daily["PREV_ENTRIES"]].head()
# Out:
#        CA  UNIT       SCP        STATION        DATE  ENTRIES   PREV_DATE  \
# 93   A002  R051  02-00-00  LEXINGTON AVE  12/27/2014  4936840  04/03/2015
# 191  A002  R051  02-00-01  LEXINGTON AVE  12/27/2014  4587693  04/03/2015
# 289  A002  R051  02-03-00  LEXINGTON AVE  12/27/2014   423299  04/03/2015
# 387  A002  R051  02-03-01  LEXINGTON AVE  12/27/2014  4529600  04/03/2015
# 485  A002  R051  02-03-02  LEXINGTON AVE  12/27/2014  4263923  04/03/2015
#
#      PREV_ENTRIES  DailyVol
# 93      5075150.0 -138310.0
# 191     4705479.0 -117786.0
# 289      473412.0  -50113.0
# 387     4648947.0 -119347.0
# 485     4381137.0 -117214.0

# %%
(all_data_daily[all_data_daily["ENTRIES"] < all_data_daily["PREV_ENTRIES"]]
    .groupby(["CA", "UNIT", "SCP", "STATION"])
    .size())
# Out:
# CA     UNIT  SCP       STATION
# A002   R051  02-00-00  LEXINGTON AVE    1
#              02-00-01  LEXINGTON AVE    1
#              02-03-00  LEXINGTON AVE    1
#              02-03-01  LEXINGTON AVE    1
#              02-03-02  LEXINGTON AVE    1
#                                        ..
# TRAM2  R469  00-00-00  RIT-ROOSEVELT    1
#              00-00-01  RIT-ROOSEVELT    1
#              00-03-00  RIT-ROOSEVELT    1
#              00-03-01  RIT-ROOSEVELT    1
#              00-05-00  RIT-ROOSEVELT    1
# Length: 4346, dtype: int64

# %%
def get_daily_counts(row, max_counter):
    counter = row["ENTRIES"] - row["PREV_ENTRIES"]
    if counter < 0:
        counter = -counter
    if counter > max_counter:
        print(row["ENTRIES"], row["PREV_ENTRIES"])
        return 0
    return counter

# %%
_ = all_data_daily.apply(get_daily_counts,axis = 1 , max_counter = 1000000)
# Out:
# 3882 5307083.0
# 5187967 86182.0
# 889146555 13309550.0
# 13173835 889047576.0
# 174 9583945.0
# 14114973 33645.0
# 9524554 14189980.0
# 1560322749 6124743.0
# 6040867 1560379065.0
# 1660958579 6726110.0
# 6651437 1661010141.0
# 1895815770 9413649.0
# 9316044 1895748455.0
# 1224695046 12037668.0
# 11924933 1224612932.0
# 83887206 837972.0
# 827414 83988333.0
# 2656 1314540.0
# 1266255 166253.0
# 117441373 4294466.0
# 506095 117444374.0
# 4215818 581836.0
# 553678444 2190952.0
# 2155483 553959356.0
# 1946174036 7627835.0
# 7540598 1946256093.0
# 403 1431948.0
# 1416830 25742.0
# 50331675 227866.0
# 211428 50408653.0
# 1120945 16345.0
# 12203 1123964.0
# 1741 3126487.0
# 3092770 24909.0
# 117449622 520845.0
# 510734 117501026.0
# 1634 1394200343.0
# 1394027842 93431.0
# 117440512 262144.0
# 262144 117440512.0
# 508 3091064.0
# 3047533 1915.0
# 24 721715541.0
# 721613409 137712.0
# 65536 67109006.0
# 67109000 65537.0
# 2123 1570700.0
# 1472569 30105.0
# 100663296 0.0
# 0 100663296.0
# ...

# %%
def get_daily_counts(row, max_counter):
    counter = row["ENTRIES"] - row["PREV_ENTRIES"]
    if counter < 0:
        # Maybe counter is reversed?
        counter = -counter
    if counter > max_counter:
        # Maybe counter was reset to 0? 
        print(row["ENTRIES"], row["PREV_ENTRIES"])
        counter = min(row["ENTRIES"], row["PREV_ENTRIES"])
    if counter > max_counter:
        # Check it again to make sure we're not still giving a counter that's too big
        return 0
    return counter

# If counter is > 1Million, then the counter might have been reset.  
# Just set it to zero as different counters have different cycle limits
# It'd probably be a good idea to use a number even significantly smaller than 1 million as the limit!

# %%
all_data_daily['DAILY ENTRIES'] = all_data_daily.apply(get_daily_counts,axis = 1 , max_counter = 1000000)
# Out:
# 3882 5307083.0
# 5187967 86182.0
# 889146555 13309550.0
# 13173835 889047576.0
# 174 9583945.0
# 14114973 33645.0
# 9524554 14189980.0
# 1560322749 6124743.0
# 6040867 1560379065.0
# 1660958579 6726110.0
# 6651437 1661010141.0
# 1895815770 9413649.0
# 9316044 1895748455.0
# 1224695046 12037668.0
# 11924933 1224612932.0
# 83887206 837972.0
# 827414 83988333.0
# 2656 1314540.0
# 1266255 166253.0
# 117441373 4294466.0
# 506095 117444374.0
# 4215818 581836.0
# 553678444 2190952.0
# 2155483 553959356.0
# 1946174036 7627835.0
# 7540598 1946256093.0
# 403 1431948.0
# 1416830 25742.0
# 50331675 227866.0
# 211428 50408653.0
# 1120945 16345.0
# 12203 1123964.0
# 1741 3126487.0
# 3092770 24909.0
# 117449622 520845.0
# 510734 117501026.0
# 1634 1394200343.0
# 1394027842 93431.0
# 117440512 262144.0
# 262144 117440512.0
# 508 3091064.0
# 3047533 1915.0
# 24 721715541.0
# 721613409 137712.0
# 65536 67109006.0
# 67109000 65537.0
# 2123 1570700.0
# 1472569 30105.0
# 100663296 0.0
# 0 100663296.0
# ...

# %%
all_data_daily.head()
# Out:
#      CA  UNIT       SCP        STATION        DATE  ENTRIES   PREV_DATE  \
# 1  A002  R051  02-00-00  LEXINGTON AVE  01/02/2015  4944000  01/01/2015
# 2  A002  R051  02-00-00  LEXINGTON AVE  01/03/2015  4945474  01/02/2015
# 3  A002  R051  02-00-00  LEXINGTON AVE  01/04/2015  4946237  01/03/2015
# 4  A002  R051  02-00-00  LEXINGTON AVE  01/05/2015  4946497  01/04/2015
# 5  A002  R051  02-00-00  LEXINGTON AVE  01/06/2015  4948380  01/05/2015
#
#    PREV_ENTRIES  DailyVol  DAILY ENTRIES
# 1     4943391.0     609.0          609.0
# 2     4944000.0    1474.0         1474.0
# 3     4945474.0     763.0          763.0
# 4     4946237.0     260.0          260.0
# 5     4946497.0    1883.0         1883.0

# %%
ca_unit_station_daily = all_data_daily.groupby(["CA", "UNIT", "STATION", "DATE",])[['DAILY ENTRIES']].sum().reset_index()

# %% [markdown]
# ca_unit_station_daily.head()

# %%
station_daily = all_data_daily.groupby(["STATION", "DATE"])[['DAILY ENTRIES']].sum().reset_index()
station_daily.head()
# Out:
#   STATION        DATE  DAILY ENTRIES
# 0   1 AVE  01/02/2015        13868.0
# 1   1 AVE  01/03/2015        21654.0
# 2   1 AVE  01/04/2015        16323.0
# 3   1 AVE  01/05/2015        13269.0
# 4   1 AVE  01/06/2015        23088.0

# %%
station_totals = station_daily.groupby('STATION').sum()\
    .sort_values('DAILY ENTRIES', ascending=False)\
    .reset_index()

station_totals.head()
# Out:
#            STATION  DAILY ENTRIES
# 0   34 ST-PENN STA     29116604.0
# 1  42 ST-GRD CNTRL     25602877.0
# 2  34 ST-HERALD SQ     19655216.0
# 3   14 ST-UNION SQ     18561419.0
# 4            86 ST     18524501.0

# %%
station_totals.head(10).hist()
# Out:
# array([[<AxesSubplot:title={'center':'DAILY ENTRIES'}>]], dtype=object)

# %%
station_daily
# Out:
#        STATION        DATE  DAILY ENTRIES
# 0        1 AVE  01/02/2015        13868.0
# 1        1 AVE  01/03/2015        21654.0
# 2        1 AVE  01/04/2015        16323.0
# 3        1 AVE  01/05/2015        13269.0
# 4        1 AVE  01/06/2015        23088.0
# ...        ...         ...            ...
# 36922  YORK ST  12/27/2014       721338.0
# 36923  YORK ST  12/28/2014         4649.0
# 36924  YORK ST  12/29/2014         3232.0
# 36925  YORK ST  12/30/2014         6952.0
# 36926  YORK ST  12/31/2014         7299.0
#
# [36927 rows x 3 columns]

# %%
STATION_TO_LOCATION = {'34 ST-PENN STA' : 'MANHATTAN' , '42 ST-GRD CNTRL' : 'MANHATTAN' , '34 ST-HERALD SQ': 'MANHATTAN', '14 ST-UNION SQ': 'MANHATTAN',
                       '86 ST':'MANHATTAN','42 ST-PA BUS TE':'MANHATTAN','42 ST-TIMES SQ':'MANHATTAN','125 ST':'MANHATTAN', 'FULTON ST':'MANHATTAN',
                      '96 ST':'MANHATTAN','CHAMBERS ST':'MANHATTAN','CHAMBERS ST':'MANHATTAN','CANAL ST	':'MANHATTAN','23 ST':'MANHATTAN',
                      '59 ST':'MANHATTAN','47-50 ST-ROCK':'MANHATTAN','MAIN ST': 'QUEENS','BARCLAYS CENTER':'BROOKLYN','ROOSEVELT AVE':'QUEENS','72 ST':'MANHATTAN','161 ST-YANKEE' : 'BRONX',
                       'ST. GEORGE':'STATEN ISLAND'}

# %%
station_daily['BORO_NM']  = station_daily['STATION'].map(STATION_TO_LOCATION)

# %%
station_daily.dropna(inplace = True)

# %%
station_daily['DATE'] = pd.to_datetime(station_daily['DATE'])

# %%
station_daily.columns
# Out:
# Index(['STATION', 'DATE', 'DAILY ENTRIES', 'BORO_NM'], dtype='object')

# %%
station_daily = station_daily.groupby(['BORO_NM','DATE','STATION'])[['DATE','DAILY ENTRIES']].sum().reset_index()

# %%
station_daily
# Out:
#             BORO_NM       DATE        STATION  DAILY ENTRIES
# 0             BRONX 2014-12-27  161 ST-YANKEE      1967362.0
# 1             BRONX 2014-12-28  161 ST-YANKEE        30188.0
# 2             BRONX 2014-12-29  161 ST-YANKEE        11822.0
# 3             BRONX 2014-12-30  161 ST-YANKEE        20949.0
# 4             BRONX 2014-12-31  161 ST-YANKEE        20915.0
# ...             ...        ...            ...            ...
# 1935  STATEN ISLAND 2015-03-30     ST. GEORGE         2880.0
# 1936  STATEN ISLAND 2015-03-31     ST. GEORGE        14362.0
# 1937  STATEN ISLAND 2015-04-01     ST. GEORGE        14633.0
# 1938  STATEN ISLAND 2015-04-02     ST. GEORGE        14589.0
# 1939  STATEN ISLAND 2015-04-03     ST. GEORGE        14454.0
#
# [1940 rows x 4 columns]

# %%
station_daily[(station_daily["DAILY ENTRIES"]>300000) & (station_daily['BORO_NM'] == 'MANHATTAN')]
# Out:
#         BORO_NM       DATE          STATION  DAILY ENTRIES
# 194   MANHATTAN 2014-12-27           125 ST      6565549.0
# 195   MANHATTAN 2014-12-27   14 ST-UNION SQ      9099550.0
# 196   MANHATTAN 2014-12-27            23 ST      5006032.0
# 197   MANHATTAN 2014-12-27  34 ST-HERALD SQ      9718664.0
# 198   MANHATTAN 2014-12-27   34 ST-PENN STA     14592292.0
# 199   MANHATTAN 2014-12-27  42 ST-GRD CNTRL     12691092.0
# 200   MANHATTAN 2014-12-27  42 ST-PA BUS TE      7585391.0
# 201   MANHATTAN 2014-12-27   42 ST-TIMES SQ      7180384.0
# 202   MANHATTAN 2014-12-27    47-50 ST-ROCK      4705123.0
# 203   MANHATTAN 2014-12-27            59 ST      5108772.0
# 204   MANHATTAN 2014-12-27            72 ST      4134849.0
# 205   MANHATTAN 2014-12-27            86 ST      9264031.0
# 206   MANHATTAN 2014-12-27            96 ST      6036867.0
# 207   MANHATTAN 2014-12-27      CHAMBERS ST      5492077.0
# 208   MANHATTAN 2014-12-27        FULTON ST      6253223.0
# ...

# %%
station_daily["DAILY ENTRIES"] = np.where((station_daily["DAILY ENTRIES"]>300000) & (station_daily['BORO_NM'] == 'MANHATTAN'), np.median(MAN_station_daily['DAILY ENTRIES']),station_daily['DAILY ENTRIES'])
# Out:
# <ipython-input-298-fa9b04990821>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   station_daily["DAILY ENTRIES"] = np.where((station_daily["DAILY ENTRIES"]>300000) & (station_daily['BORO_NM'] == 'MANHATTAN'), np.median(MAN_station_daily['DAILY ENTRIES']),station_daily['DAILY ENTRIES'])

# %%
BRONX_station_daily = station_daily[station_daily['BORO_NM'] == 'BRONX']

# %%
np.median(BRONX_station_daily['DAILY ENTRIES'])
# Out:
# 23375.0

# %%
station_daily["DAILY ENTRIES"] = np.where((station_daily["DAILY ENTRIES"]>1000000) & (station_daily['BORO_NM'] == 'BRONX'), np.median(BRONX_station_daily['DAILY ENTRIES']),station_daily['DAILY ENTRIES'])
# Out:
# <ipython-input-299-0fad332b6813>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   station_daily["DAILY ENTRIES"] = np.where((station_daily["DAILY ENTRIES"]>1000000) & (station_daily['BORO_NM'] == 'BRONX'), np.median(BRONX_station_daily['DAILY ENTRIES']),station_daily['DAILY ENTRIES'])

# %%
BROOKLYN_station_daily = station_daily[station_daily['BORO_NM'] == 'BROOKLYN']

# %%
np.median(BROOKLYN_station_daily['DAILY ENTRIES'])
# Out:
# 41750.0

# %%
station_daily["DAILY ENTRIES"] = np.where((station_daily["DAILY ENTRIES"]>300000) & (station_daily['BORO_NM'] == 'BROOKLYN'), np.median(BROOKLYN_station_daily['DAILY ENTRIES']),station_daily['DAILY ENTRIES'])
# Out:
# <ipython-input-300-4ed3ade84f71>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   station_daily["DAILY ENTRIES"] = np.where((station_daily["DAILY ENTRIES"]>300000) & (station_daily['BORO_NM'] == 'BROOKLYN'), np.median(BROOKLYN_station_daily['DAILY ENTRIES']),station_daily['DAILY ENTRIES'])

# %%
QUEENS_station_daily = station_daily[station_daily['BORO_NM'] == 'QUEENS']

# %%
np.median(QUEENS_station_daily['DAILY ENTRIES'])
# Out:
# 48593.0

# %%
station_daily["DAILY ENTRIES"] = np.where((station_daily["DAILY ENTRIES"]>300000) & (station_daily['BORO_NM'] == 'QUEENS'), np.median(QUEENS_station_daily['DAILY ENTRIES']),station_daily['DAILY ENTRIES'])
# Out:
# <ipython-input-301-d42b171929d4>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   station_daily["DAILY ENTRIES"] = np.where((station_daily["DAILY ENTRIES"]>300000) & (station_daily['BORO_NM'] == 'QUEENS'), np.median(QUEENS_station_daily['DAILY ENTRIES']),station_daily['DAILY ENTRIES'])

# %%
STATEN_station_daily = station_daily[station_daily['BORO_NM'] == 'STATEN ISLAND']

# %%
np.median(STATEN_station_daily['DAILY ENTRIES'])
# Out:
# 13100.0

# %%
station_daily["DAILY ENTRIES"] = np.where((station_daily["DAILY ENTRIES"]>300000) & (station_daily['BORO_NM'] == 'STATEN ISLAND'), np.median(STATEN_station_daily['DAILY ENTRIES']),station_daily['DAILY ENTRIES'])
# Out:
# <ipython-input-302-fdfa2db4e137>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   station_daily["DAILY ENTRIES"] = np.where((station_daily["DAILY ENTRIES"]>300000) & (station_daily['BORO_NM'] == 'STATEN ISLAND'), np.median(STATEN_station_daily['DAILY ENTRIES']),station_daily['DAILY ENTRIES'])

# %%
MAN_station_daily = station_daily[station_daily['BORO_NM'] == 'MANHATTAN']

# %%
MAN_station_daily["DAILY ENTRIES"] = np.where(MAN_station_daily["DAILY ENTRIES"]>300000, np.median(MAN_station_daily['DAILY ENTRIES']),MAN_station_daily['DAILY ENTRIES'])
# Out:
# <ipython-input-212-dd2e2dbf41b0>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   MAN_station_daily["DAILY ENTRIES"] = np.where(MAN_station_daily["DAILY ENTRIES"]>1000000, np.median(MAN_station_daily['DAILY ENTRIES']),MAN_station_daily['DAILY ENTRIES'])

# %%
station_daily[station_daily['DAILY ENTRIES']>300000]
# Out:
# Empty DataFrame
# Columns: [BORO_NM, DATE, STATION, DAILY ENTRIES]
# Index: []

# %%
station_daily = station_daily[station_daily['DATE'].map(lambda x: x.month) <= 3]

# %%
station_daily['DAILY ENTRIES'].max()
# Out:
# 649100.0

# %%
sns.lineplot(data = station_daily , x = 'DATE' , y = 'DAILY ENTRIES' , hue = 'BORO_NM',ci = None)
# Out:
# <AxesSubplot:xlabel='DATE', ylabel='DAILY ENTRIES'>

# %%
station_totals.head(20)
# Out:
#             STATION  DAILY ENTRIES
# 0    34 ST-PENN STA     29116604.0
# 1   42 ST-GRD CNTRL     25602877.0
# 2   34 ST-HERALD SQ     19655216.0
# 3    14 ST-UNION SQ     18561419.0
# 4             86 ST     18524501.0
# 5   42 ST-PA BUS TE     17175966.0
# 6    42 ST-TIMES SQ     15349105.0
# 7            125 ST     13394961.0
# 8         FULTON ST     12846576.0
# 9             96 ST     12230356.0
# 10   59 ST-COLUMBUS     11510539.0
# 11      CHAMBERS ST     11008373.0
# 12         CANAL ST     10763077.0
# 13            23 ST     10567519.0
# 14            59 ST     10162908.0
# 15    47-50 ST-ROCK      9411490.0
# 16          MAIN ST      9393397.0
# 17  BARCLAYS CENTER      8327558.0
# 18    ROOSEVELT AVE      8254952.0
# 19            72 ST      8224659.0

# %%
station_totals['BORO_NM']  = station_totals['STATION'].map(STATION_TO_LOCATION)

# %%
station_totals[station_totals['STATION'] == 'ST. GEORGE']
# Out:
#        STATION  DAILY ENTRIES        BORO_NM
# 93  ST. GEORGE      2935782.0  STATEN ISLAND

# %%
station_totals['STATION']
# Out:
# 0       34 ST-PENN STA
# 1      42 ST-GRD CNTRL
# 2      34 ST-HERALD SQ
# 3       14 ST-UNION SQ
# 4                86 ST
#             ...
# 376        BEACH 44 ST
# 377        BEACH 98 ST
# 378         PATH WTC 2
# 379      BROAD CHANNEL
# 380       BEACH 105 ST
# Name: STATION, Length: 381, dtype: object

# %%
station_totals_copy = station_totals.dropna()

# %%
station_totals_copy
# Out:
#             STATION  DAILY ENTRIES        BORO_NM
# 0    34 ST-PENN STA     29116604.0      MANHATTAN
# 1   42 ST-GRD CNTRL     25602877.0      MANHATTAN
# 2   34 ST-HERALD SQ     19655216.0      MANHATTAN
# 3    14 ST-UNION SQ     18561419.0      MANHATTAN
# 4             86 ST     18524501.0      MANHATTAN
# 5   42 ST-PA BUS TE     17175966.0      MANHATTAN
# 6    42 ST-TIMES SQ     15349105.0      MANHATTAN
# 7            125 ST     13394961.0      MANHATTAN
# 8         FULTON ST     12846576.0      MANHATTAN
# 9             96 ST     12230356.0      MANHATTAN
# 11      CHAMBERS ST     11008373.0      MANHATTAN
# 13            23 ST     10567519.0      MANHATTAN
# 14            59 ST     10162908.0      MANHATTAN
# 15    47-50 ST-ROCK      9411490.0      MANHATTAN
# 16          MAIN ST      9393397.0         QUEENS
# 17  BARCLAYS CENTER      8327558.0       BROOKLYN
# 18    ROOSEVELT AVE      8254952.0         QUEENS
# 19            72 ST      8224659.0      MANHATTAN
# ...

# %%
station_daily_34_ST_PENN = station_daily[station_daily["STATION"] =='34 ST-PENN STA']

# %%
station_daily_34_ST_PENN.DATE = pd.to_datetime(station_daily_34_ST_PENN.DATE)
# Out:
# /home/calvinyu/miniconda3/envs/metis/lib/python3.8/site-packages/pandas/core/generic.py:5491: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[name] = value

# %%
station_daily_34_ST_PENN['BORO_NM'] = 'MANHATTAN'
# Out:
# <ipython-input-85-bdaa4ecbc3e9>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   station_daily_34_ST_PENN['BORO_NM'] = 'MANHATTAN'

# %%
Jan_34_ST_PENN = station_daily_34_ST_PENN[station_daily_34_ST_PENN.DATE.dt.month == 1]

# %%
Feb_34_ST_PENN = station_daily_34_ST_PENN[station_daily_34_ST_PENN.DATE.dt.month == 2]

# %%
Mar_34_ST_PENN = station_daily_34_ST_PENN[station_daily_34_ST_PENN.DATE.dt.month == 3]

# %%
Jan_to_Mar_ST_PENN = pd.concat([Jan_34_ST_PENN,Feb_34_ST_PENN,Mar_34_ST_PENN])

# %%
plt.figure(figsize=(15,5))
plt.plot(Jan_to_Mar_ST_PENN['DATE'],Jan_to_Mar_ST_PENN['DAILY ENTRIES'])
plt.ylabel('# of Entries')
plt.xlabel('Date')
plt.xticks(rotation=45)
plt
# Out:
# <module 'matplotlib.pyplot' from '/home/calvinyu/miniconda3/envs/metis/lib/python3.8/site-packages/matplotlib/pyplot.py'>

# %%
Nypd_df_Jan_to_Mar.groupby(['DATE', 'BORO_NM'])[['BORO_NM']].count()
# Out:
#                         BORO_NM
# DATE     BORO_NM
# 1/1/2015 BRONX              305
#          BROOKLYN           627
#          MANHATTAN          430
#          QUEENS             340
#          STATEN ISLAND       69
# ...                         ...
# 3/9/2015 BRONX              259
#          BROOKLYN           367
#          MANHATTAN          288
#          QUEENS             265
#          STATEN ISLAND      114
#
# [450 rows x 1 columns]
